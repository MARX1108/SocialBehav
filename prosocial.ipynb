# %%
import pandas as pd

df = pd.read_csv("prosocialEPFbrain.csv")
df.head()
df.shape
# Out:
# (3328, 92)

# %%
truedf = df[df['y']==1]
falsedf = df[df['y']==0]

assert truedf.shape[0]+falsedf.shape[0] == df.shape[0]
truedf = truedf.sample(n=200, replace=True )
falsedf = falsedf.sample(n=200, replace=True)
finaldf = pd.concat([truedf, falsedf])
assert finaldf.shape[0] == 400

#finaldf = finaldf.drop(['sex'], axis=1)


cat_vars = ['sex']
for var in cat_vars:
    cat_list='var'+'_'+var
    cat_list = pd.get_dummies(finaldf[var], prefix=var)
    finaldf=finaldf.join(cat_list)

data_vars=finaldf.columns.values.tolist()
to_keep=[i for i in data_vars if i not in cat_vars]

finaldf=finaldf[to_keep]
finaldf.shape

X_train = finaldf[finaldf.columns[:91]]
y_train = finaldf['y']

print(X_train.shape)
print(y_train.shape)
# Out:
# (566, 91)
# (566,)

# %%
accuracy = []
for i in range(5000):

    truedf = truedf.sample(n=200, replace=True )
    falsedf = falsedf.sample(n=200, replace=True)
    finaldf = pd.concat([truedf, falsedf])

    cat_vars = ['sex']
    for var in cat_vars:
        cat_list='var'+'_'+var
        cat_list = pd.get_dummies(finaldf[var], prefix=var)
        finaldf=finaldf.join(cat_list)

    data_vars=finaldf.columns.values.tolist()
    to_keep=[i for i in data_vars if i not in cat_vars]

    finaldf=finaldf[to_keep]
    finaldf.shape

    X_train = finaldf[finaldf.columns[:91]]
    y_train = finaldf['y']

    logreg = LogisticRegression()
    logreg.fit(X_train, y_train)
    accuracy.append(logreg.score(X_train, y_train))
# Out:
# /Users/marxw/Desktop/andlab/code/venv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/marxw/Desktop/andlab/code/venv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics


logreg = LogisticRegression()
fit = logreg.fit(X_train, y_train)
#print(fit.score())
#print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_train, y_train)))
# Out:
# /Users/marxw/Desktop/andlab/code/venv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/2b/d_d_lc293lz44k46wtvb1nwc0000gn/T/ipykernel_13894/3537393826.py in <module>
#       5 logreg = LogisticRegression()
#       6 fit = logreg.fit(X_train, y_train)
# ----> 7 print(fit.score())
# ...
